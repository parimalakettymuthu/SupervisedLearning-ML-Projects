# %%
import pandas as pd 
import seaborn as sns
#loading data
hotelBooking_df = pd.read_csv("data.csv")
hotelBooking_df
# Out:
#         Unnamed: 0    Type  IsCanceled  LeadTime  ArrivalDateYear  \
# 0                1  resort           0       342             2015
# 1                2  resort           0       737             2015
# 2                3  resort           0         7             2015
# 3                4  resort           0        13             2015
# 4                5  resort           0        14             2015
# ...            ...     ...         ...       ...              ...
# 119385      119386    city           0        23             2017
# 119386      119387    city           0       102             2017
# 119387      119388    city           0        34             2017
# 119388      119389    city           0       109             2017
# 119389      119390    city           0       205             2017
#
#        ArrivalDateMonth  ArrivalDateWeekNumber  ArrivalDateDayOfMonth  \
# 0                  July                     27                      1
# ...

# %%
#Print first several rows
hotelBooking_df.head(10)
# Out:
#    Unnamed: 0    Type  IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           1  resort           0       342             2015             July
# 1           2  resort           0       737             2015             July
# 2           3  resort           0         7             2015             July
# 3           4  resort           0        13             2015             July
# 4           5  resort           0        14             2015             July
# 5           6  resort           0        14             2015             July
# 6           7  resort           0         0             2015             July
# 7           8  resort           0         9             2015             July
# 8           9  resort           1        85             2015             July
# 9          10  resort           1        75             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# ...

# %%
#Shape of the data frame
hotelBooking_df.shape
# Out:
# (119390, 33)

# %%
hotelBooking_df.columns
# Out:
# Index(['Unnamed: 0', 'Type', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
#Handling Anomaly - drop duplicates
hotelBooking_df.drop_duplicates()
# Out:
#         Unnamed: 0    Type  IsCanceled  LeadTime  ArrivalDateYear  \
# 0                1  resort           0       342             2015
# 1                2  resort           0       737             2015
# 2                3  resort           0         7             2015
# 3                4  resort           0        13             2015
# 4                5  resort           0        14             2015
# ...            ...     ...         ...       ...              ...
# 119385      119386    city           0        23             2017
# 119386      119387    city           0       102             2017
# 119387      119388    city           0        34             2017
# 119388      119389    city           0       109             2017
# 119389      119390    city           0       205             2017
#
#        ArrivalDateMonth  ArrivalDateWeekNumber  ArrivalDateDayOfMonth  \
# 0                  July                     27                      1
# ...

# %%
hotelBooking_df.dropna(axis = 'columns')
# Out:
#         Unnamed: 0    Type  IsCanceled  LeadTime  ArrivalDateYear  \
# 0                1  resort           0       342             2015
# 1                2  resort           0       737             2015
# 2                3  resort           0         7             2015
# 3                4  resort           0        13             2015
# 4                5  resort           0        14             2015
# ...            ...     ...         ...       ...              ...
# 119385      119386    city           0        23             2017
# 119386      119387    city           0       102             2017
# 119387      119388    city           0        34             2017
# 119388      119389    city           0       109             2017
# 119389      119390    city           0       205             2017
#
#        ArrivalDateMonth  ArrivalDateWeekNumber  ArrivalDateDayOfMonth  \
# 0                  July                     27                      1
# ...

# %%
#Data columns after dropping NAs
hotelBooking_df.columns
# Out:
# Index(['Unnamed: 0', 'Type', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
#Obtain summary statistics
hotelBooking_df.describe()
# Out:
#           Unnamed: 0     IsCanceled       LeadTime  ArrivalDateYear  \
# count  119390.000000  119390.000000  119390.000000    119390.000000
# mean    59695.500000       0.370416     104.011416      2016.156554
# std     34465.068657       0.482918     106.863097         0.707476
# min         1.000000       0.000000       0.000000      2015.000000
# 25%     29848.250000       0.000000      18.000000      2016.000000
# 50%     59695.500000       0.000000      69.000000      2016.000000
# 75%     89542.750000       1.000000     160.000000      2017.000000
# max    119390.000000       1.000000     737.000000      2017.000000
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# count          119390.000000          119390.000000         119390.000000
# mean               27.165173              15.798241              0.927599
# std                13.605138               8.780829              0.998613
# ...

# %%
#correlation matrix
hotelBooking_matrix = hotelBooking_df.corr()
hotelBooking_matrix
# Out:
#                              Unnamed: 0  IsCanceled  LeadTime  \
# Unnamed: 0                     1.000000   -0.242238  0.006708
# IsCanceled                    -0.242238    1.000000  0.293123
# LeadTime                       0.006708    0.293123  1.000000
# ArrivalDateYear                0.299040    0.016660  0.040142
# ArrivalDateWeekNumber         -0.053586    0.008148  0.126871
# ArrivalDateDayOfMonth          0.009368   -0.006130  0.002268
# StaysInWeekendNights          -0.147381   -0.001791  0.085671
# StaysInWeekNights             -0.205002    0.024765  0.165799
# Adults                        -0.010250    0.060017  0.119519
# Children                      -0.020066    0.005048 -0.037622
# Babies                        -0.027776   -0.032491 -0.020915
# IsRepeatedGuest               -0.018180   -0.084793 -0.124410
# PreviousCancellations         -0.018089    0.110133  0.086042
# PreviousBookingsNotCanceled   -0.000193   -0.057358 -0.073548
# ...

# %%
sns.heatmap(hotelBooking_matrix)
# Out:
# <AxesSubplot:>
