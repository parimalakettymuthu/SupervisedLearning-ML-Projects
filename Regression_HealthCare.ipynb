# %%
#!pip install pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing the required datafile
healthcare = pd.read_csv("/home/parimala/Downloads/l2_data.csv")

# %%
#Shape attribute helps to identify the number of observations 
# and columns in the dataset
healthcare.shape
# Out:
# (7393, 20)

# %%
#Displaying the 1st 5 records from healthcare dataset
healthcare.head(5)
# Out:
#    physician_id  physician_efficiency metro_area physician_working_specialty  \
# 0           866                  0.10    Chicago                  Nephrology
# 1          4766                  0.12    Chicago    Hospital Based Physician
# 2          7088                  0.12    Chicago                  Nephrology
# 3          2808                  0.12    Chicago                  Nephrology
# 4          4040                  0.13     Dallas                  Nephrology
#
#   physician_gender physician_credential  \
# 0                M              UNKNOWN
# 1                M              UNKNOWN
# 2                F              UNKNOWN
# 3                F              UNKNOWN
# 4                F              UNKNOWN
#
#                                 physician_med_school  \
# 0                                              OTHER
# 1                                              OTHER
# 2                                              OTHER
# ...

# %%
healthcare.describe()
# Out:
#        physician_id  physician_efficiency  physician_graduation_year  \
# count   7393.000000           7393.000000                6674.000000
# mean    4998.183417              1.056228                2002.603536
# std     2882.632252              0.355256                 170.391845
# min        2.000000              0.100000                1961.000000
# 25%     2495.000000              0.860000                1991.000000
# 50%     5009.000000              1.010000                2000.000000
# 75%     7475.000000              1.200000                2008.000000
# max    10002.000000              2.990000                9999.000000
#
#        bump_feature  engineered_feature_1  engineered_feature_2  \
# count   7393.000000           7393.000000           7393.000000
# mean    4948.712836              1.088763              1.067009
# std     2917.906257              0.409342              0.249731
# min       12.000000              0.047000              0.047000
# ...

# %%
#Checking the data schema information
healthcare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7393 entries, 0 to 7392
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   physician_id                     7393 non-null   int64
#  1   physician_efficiency             7393 non-null   float64
#  2   metro_area                       7393 non-null   object
#  3   physician_working_specialty      7393 non-null   object
#  4   physician_gender                 7393 non-null   object
#  5   physician_credential             7393 non-null   object
#  6   physician_med_school             7393 non-null   object
#  7   physician_graduation_year        6674 non-null   float64
#  8   bump_feature                     7393 non-null   int64
#  9   engineered_feature_1             7393 non-null   float64
#  10  engineered_feature_2             7393 non-null   float64
#  11  engineered_feature_3             7393 non-null   float64
# ...

# %%
#Dropping the duplicates, results shows there's no duplicate records in the dataset
hlth_care_df = healthcare.drop_duplicates()
hlth_care_df.shape
# Out:
# (7393, 20)

# %%
#Checking for null values, result shows there's only one field having null values
hlth_care_df.isnull().sum().sort_values(ascending=False)
# Out:
# physician_graduation_year          719
# physician_id                         0
# engineered_feature_3                 0
# num_medicare_patients                0
# medicare_engineered_6                0
# medicare_engineered_5                0
# medicare_enginerred_4                0
# medicare_engineered_3                0
# medicare_engineered_2                0
# medicare_engineered_1                0
# engineered_feature_2                 0
# physician_efficiency                 0
# engineered_feature_1                 0
# bump_feature                         0
# physician_med_school                 0
# physician_credential                 0
# physician_gender                     0
# physician_working_specialty          0
# metro_area                           0
# medicare_patient_hcc_risk_score      0
# dtype: int64

# %%
plt.hist(hlth_care_df['engineered_feature_1'], color='r', bins=10, label="Engineered feature 1",alpha=0.6)
plt.hist(hlth_care_df['engineered_feature_2'], color='b', bins=10, label="Engineered feature 2",alpha=0.6)
plt.hist(hlth_care_df['engineered_feature_3'], color='g', bins=10, label="Engineered feature 3",alpha=0.6)
plt.xlabel("Engineered feature")
plt.ylabel("Frequency")
plt.legend()

# %%
plt.hist(hlth_care_df["medicare_engineered_1"], bins=15, color='r')
# Out:
# (array([226., 324., 408., 726., 701., 699., 872., 907., 701., 540., 499.,
#         379., 187., 134.,  90.]),
#  array([1.        , 1.26666667, 1.53333333, 1.8       , 2.06666667,
#         2.33333333, 2.6       , 2.86666667, 3.13333333, 3.4       ,
#         3.66666667, 3.93333333, 4.2       , 4.46666667, 4.73333333,
#         5.        ]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(hlth_care_df["medicare_engineered_1"], bins=15, alpha=0.6, color='r', label="Medicare Engineered 1")
plt.hist(hlth_care_df["medicare_engineered_2"], bins=10,alpha=0.6, color='b', label="Medicare Engineered 2")
plt.hist(hlth_care_df["medicare_engineered_3"], bins=10,alpha=0.6, color='g', label="Medicare Engineered 3")
plt.xlabel("Medicare Engineered")
plt.ylabel("Frequency")
plt.legend()

# %%
plt.hist(hlth_care_df["medicare_enginerred_4"], bins=15,alpha=0.6, color='r', label="Medicare Engineered 4")
plt.hist(hlth_care_df["medicare_engineered_5"], bins=10,alpha=0.6, color='b', label="Medicare Engineered 5")
plt.hist(hlth_care_df["medicare_engineered_6"], bins=10,alpha=0.6, color='g', label="Medicare Engineered 6")
plt.xlabel("Medicare Engineered")
plt.ylabel("Frequency")
plt.legend()

# %%
plt.boxplot(hlth_care_df["medicare_engineered_1"], vert=False, showmeans=True)
plt.boxplot(hlth_care_df["medicare_engineered_2"], vert=False, showmeans=True)
plt.ylabel("Medicare Engineered")
# Out:
# Text(0, 0.5, 'Medicare Engineered')

# %%
hlth_care_df.corr()
# Out:
#                                  physician_id  physician_efficiency  \
# physician_id                         1.000000             -0.000238
# physician_efficiency                -0.000238              1.000000
# physician_graduation_year           -0.032548              0.005756
# bump_feature                         0.017047              0.895089
# engineered_feature_1                -0.007993              0.261837
# engineered_feature_2                 0.016665              0.231081
# engineered_feature_3                -0.010132              0.319219
# medicare_engineered_1                0.016997              0.086232
# medicare_engineered_2                0.026023              0.081228
# medicare_engineered_3                0.013255              0.050238
# medicare_enginerred_4               -0.005456              0.021475
# medicare_engineered_5                0.002505              0.024428
# medicare_engineered_6                0.022504              0.085179
# ...

# %% [markdown]
# #Variables - bump_feature & physician_efficiency having correlation value as 0.895089 which falls into high range; so will remove bump_feature for model execution
# #medicare_engineered_1 & medicare_engineered_2 having a correlation value as 0.949004 which falls into high range; Hence will remove
# #this variable as well.
# #These two variables will be removed to avoid multicolinearity issues

# %%
hlth_care_df["physician_working_specialty"].value_counts()
# Out:
# Family Practice                        1031
# Internal Medicine                      1001
# OB/GYN                                  470
# Emergency Medicine                      323
# Cardiovascular - Non-interventional     282
#                                        ...
# Pediatric Surgery                         1
# Pediatric Otolaryngology                  1
# Otology                                   1
# Reproductive Endocrinology                1
# Pediatric Neurology                       1
# Name: physician_working_specialty, Length: 68, dtype: int64

# %%
res_phy_specialty = hlth_care_df["physician_working_specialty"].value_counts()>400
plt.hist(res_phy_specialty)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_303354/3000758934.py in <module>
#       1 res_phy_specialty = hlth_care_df["physician_working_specialty"].value_counts()>400
# ----> 2 plt.hist(res_phy_specialty)
#
# ...

# %%
from sklearn.model_selection import train_test_split
X = 
y = hlth_care_df[""]
X_train, X_test, y_train, y_test = train_test_split()
