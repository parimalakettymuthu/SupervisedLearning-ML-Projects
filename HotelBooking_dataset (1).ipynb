# %%
import pandas as pd 
import seaborn as sns
#loading data
hotelBooking_df = pd.read_csv("modified_dataset1.csv")
hotelBooking_df
# Out:
#           0  Type  IsCanceled  LeadTime ArrivalDateYear  ArrivalDateMonth  \
# 0      city     0           6      2015            July                27
# 1      city     1          88      2015            July                27
# 2      city     1          65      2015            July                27
# 3      city     1          92      2015            July                27
# 4      city     1         100      2015            July                27
# ...     ...   ...         ...       ...             ...               ...
# 79325  city     0          23      2017          August                35
# 79326  city     0         102      2017          August                35
# 79327  city     0          34      2017          August                35
# 79328  city     0         109      2017          August                35
# 79329  city     0         205      2017          August                35
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# ...

# %%
#Print first several rows
hotelBooking_df.head(10)
# Out:
#       0  Type  IsCanceled  LeadTime ArrivalDateYear  ArrivalDateMonth  \
# 0  city     0           6      2015            July                27
# 1  city     1          88      2015            July                27
# 2  city     1          65      2015            July                27
# 3  city     1          92      2015            July                27
# 4  city     1         100      2015            July                27
# 5  city     1          79      2015            July                27
# 6  city     0           3      2015            July                27
# 7  city     1          63      2015            July                27
# 8  city     1          62      2015            July                27
# 9  city     1          62      2015            July                27
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                      1                      0                     2
# ...

# %%
#Shape of the data frame
hotelBooking_df.shape
# Out:
# (79330, 33)

# %%
hotelBooking_df.columns
# Out:
# Index(['0', 'Type', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
#Handling Anomaly - drop duplicates
hotelBooking_df.drop_duplicates()
# Out:
#           0  Type  IsCanceled  LeadTime ArrivalDateYear  ArrivalDateMonth  \
# 0      city     0           6      2015            July                27
# 1      city     1          88      2015            July                27
# 2      city     1          65      2015            July                27
# 3      city     1          92      2015            July                27
# 4      city     1         100      2015            July                27
# ...     ...   ...         ...       ...             ...               ...
# 79325  city     0          23      2017          August                35
# 79326  city     0         102      2017          August                35
# 79327  city     0          34      2017          August                35
# 79328  city     0         109      2017          August                35
# 79329  city     0         205      2017          August                35
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# ...

# %%
hotelBooking_cleaned = hotelBooking_df.dropna(axis='columns')
hotelBooking_cleaned
# Out:
#           0  Type  IsCanceled  LeadTime ArrivalDateYear  ArrivalDateMonth  \
# 0      city     0           6      2015            July                27
# 1      city     1          88      2015            July                27
# 2      city     1          65      2015            July                27
# 3      city     1          92      2015            July                27
# 4      city     1         100      2015            July                27
# ...     ...   ...         ...       ...             ...               ...
# 79325  city     0          23      2017          August                35
# 79326  city     0         102      2017          August                35
# 79327  city     0          34      2017          August                35
# 79328  city     0         109      2017          August                35
# 79329  city     0         205      2017          August                35
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# ...

# %%
#Data columns after dropping NAs
hotelBooking_cleaned.columns
# Out:
# Index(['0', 'Type', 'IsCanceled', 'LeadTime', 'ArrivalDateYear',
#        'ArrivalDateMonth', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Children', 'Babies',
#        'AssignedRoomType', 'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList'],
#       dtype='object')

# %%
hotelBooking_cleaned.shape
# Out:
# (79330, 18)

# %%
#Checking whether data containing any null data
hotelBooking_cleaned.isnull().sum()
#hotelBooking_cleaned.to_csv("out.csv")
# Out:
# 0                        0
# Type                     0
# IsCanceled               0
# LeadTime                 0
# ArrivalDateYear          0
# ArrivalDateMonth         0
# ArrivalDateWeekNumber    0
# ArrivalDateDayOfMonth    0
# StaysInWeekendNights     0
# StaysInWeekNights        0
# Children                 0
# Babies                   0
# AssignedRoomType         0
# BookingChanges           0
# DepositType              0
# Agent                    0
# Company                  0
# DaysInWaitingList        0
# dtype: int64

# %%
#Using Seaborn to check the null values
sns.heatmap(hotelBooking_cleaned.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
#Obtain summary statistics
hotelBooking_cleaned.describe()
# Out:
#                Type    IsCanceled      LeadTime  ArrivalDateMonth  \
# count  79330.000000  79330.000000  79330.000000      79330.000000
# mean       0.417270    109.735724   2016.174285         27.177449
# std        0.493111    110.948526      0.699181         13.398523
# min        0.000000      0.000000   2015.000000          1.000000
# 25%        0.000000     23.000000   2016.000000         17.000000
# 50%        0.000000     74.000000   2016.000000         27.000000
# 75%        1.000000    163.000000   2017.000000         38.000000
# max        1.000000    629.000000   2017.000000         53.000000
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# count           79330.000000           79330.000000          79330.000000
# mean               15.786625               0.795185              2.182957
# std                 8.728451               0.885026              1.456416
# min                 1.000000               0.000000              0.000000
# ...

# %%
#correlation matrix
hotelBooking_matrix = hotelBooking_cleaned.corr()
hotelBooking_r_index = hotelBooking_matrix.index
hotelBooking_matrix
# Out:
#                            Type  IsCanceled  LeadTime  ArrivalDateMonth  \
# Type                   1.000000    0.309242 -0.003004          0.001580
# IsCanceled             0.309242    1.000000  0.027876          0.130392
# LeadTime              -0.003004    0.027876  1.000000         -0.543027
# ArrivalDateMonth       0.001580    0.130392 -0.543027          1.000000
# ArrivalDateWeekNumber -0.004331    0.014502 -0.002910          0.061681
# ArrivalDateDayOfMonth -0.007343   -0.023913  0.034851         -0.001043
# StaysInWeekendNights   0.048704    0.058361  0.066234         -0.008598
# StaysInWeekNights      0.053054    0.115792  0.067558          0.006947
# Children              -0.030186   -0.030333 -0.008407          0.005450
# Agent                  0.127457    0.114807 -0.168219          0.034894
# Company               -0.033772   -0.056391  0.003189         -0.005143
#
#                        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  \
# ...

# %%
hotelBooking_r_index.shape #Out of 33 columns, only 19 columns were accounted for Corr Matrix
print("Correlation Indexed columns: ",hotelBooking_r_index)
print("\n\nCorrelation Indexed Columns shape: ",hotelBooking_r_index.shape)
# Out:
# Correlation Indexed columns:  Index(['Type', 'IsCanceled', 'LeadTime', 'ArrivalDateMonth',
#        'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Children', 'Agent',
#        'Company'],
#       dtype='object')
#
#
# Correlation Indexed Columns shape:  (11,)

# %%
sns.heatmap(hotelBooking_matrix)
sns.heatmap(hotelBooking_matrix[hotelBooking_r_index].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Feature importance 
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score as acc

# %%
X_train, X_test, y_train, y_test = train_test_split()
